# %%
import numpy as np

# %%
x = "Pakistan is a great country!"

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 x.getattribute()
#
# AttributeError: 'str' object has no attribute 'getattribute'

# %%
pd = (1,2,3,4,5)

# %%
pd.read_csv?
# Out:
# Object `pd.read_csv` not found.

# %%
CD = 'C:\PGC.csv'

with open(CD, 'r') as reader:
    for index, line in enumerate(reader.readlines()):
        # read just the first 10 lines
        if (index < 1000):
            print(index, line)
# Out:
# 0 ï»¿Date,ItemID,Category,Items Description,Unit, Qty , Rate , Amount ,Issued For,Remarks,Seq Code
#
# 1 01-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 2 01-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 3 01-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 4 01-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 5 02-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 6 02-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 7 02-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 8 02-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 9 03-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 10 03-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 11 03-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 12 03-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 13 04-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 14 04-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 15 04-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 16 04-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 17 05-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 18 05-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 19 05-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 20 05-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 21 06-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 22 06-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 23 06-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 24 06-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 25 07-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 26 07-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 27 07-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 28 07-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 29 08-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 30 08-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 31 08-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 32 08-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 33 09-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 34 09-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 35 09-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 36 09-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 37 10-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 38 10-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 39 10-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 40 10-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 41 11-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 42 11-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 43 11-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 44 11-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 45 12-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 46 12-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 47 12-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 48 12-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 49 13-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 50 13-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 51 13-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 52 13-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 53 14-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 54 14-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 55 14-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 56 14-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 57 15-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 58 15-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 59 15-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 60 15-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 61 16-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 62 16-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 63 16-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 64 16-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 65 17-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 66 17-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 67 17-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 68 17-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 69 18-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 70 18-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 71 18-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 72 18-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 73 19-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 74 19-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 75 19-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 76 19-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 77 20-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 78 20-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 79 20-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 80 20-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 81 21-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 82 21-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 83 21-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 84 21-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 85 22-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 86 22-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 87 22-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 88 22-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 89 23-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 90 23-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 91 23-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 92 23-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 93 24-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 94 24-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 95 24-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 96 24-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 97 25-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 98 25-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 99 25-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 100 25-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 101 26-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 102 26-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 103 26-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 104 26-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 105 27-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 106 27-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 107 27-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 108 27-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 109 28-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 110 28-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 111 28-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 112 28-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 113 29-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 114 29-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 115 29-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 116 29-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 117 30-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 118 30-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 119 30-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 120 30-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23
#
# 121 31-Aug-23,SLG,Dairy Silage,Silage,Silage," 2,500 ", 10 ," 25,000 ",Friesian,,ZS-Aug-23
#
# 122 31-Aug-23,SLG,Dairy Silage,Silage,Silage, 300 , 10 ," 3,000 ",Bhagnari,,ZS-Aug-23
#
# 123 31-Aug-23,SLG,Dairy Silage,Silage,Silage, 400 , 10 ," 4,000 ",Brahman,,ZS-Aug-23
#
# 124 31-Aug-23,SLG,Dairy Silage,Silage,Silage, 50 , 10 , 500 ,Camel,,ZS-Aug-23

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\PGC.csv', decimal=',')
del df['Remarks']
df['Date'] = pd.to_datetime(df['Date'])
df = df.rename(columns=lambda x: x.strip())
df['Qty'] = df['Qty'].astype(np.int64) 
df['Amount'] = df['Amount'].astype(np.int64) 
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               124 non-null    datetime64[ns]
#  1   ItemID             124 non-null    object
#  2   Category           124 non-null    object
#  3   Items Description  124 non-null    object
#  4   Unit               124 non-null    object
#  5   Qty                124 non-null    int64
#  6   Rate               124 non-null    int64
#  7   Amount             124 non-null    int64
#  8   Issued For         124 non-null    object
#  9   Seq Code           124 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 9.8+ KB
#         Date ItemID      Category Items Description    Unit  Qty  Rate  \
# 0 2023-08-01    SLG  Dairy Silage            Silage  Silage    2    10
# 1 2023-08-01    SLG  Dairy Silage            Silage  Silage  300    10
# 2 2023-08-01    SLG  Dairy Silage            Silage  Silage  400    10
# 3 2023-08-01    SLG  Dairy Silage            Silage  Silage   50    10
# 4 2023-08-02    SLG  Dairy Silage            Silage  Silage    2    10
#
#    Amount Issued For   Seq Code
# 0      25   Friesian  ZS-Aug-23
# 1       3   Bhagnari  ZS-Aug-23
# 2       4    Brahman  ZS-Aug-23
# 3     500      Camel  ZS-Aug-23
# 4      25   Friesian  ZS-Aug-23
